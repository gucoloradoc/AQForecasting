# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
# ms-python.python added
import os
try:
	os.chdir(os.path.join(os.getcwd(), '../..'))
	print(os.getcwd())
except:
	pass

# %%
import pandas as pd
import numpy as np


dframe=pd.read_pickle('./AMMfull.pkl')

# %%
#dframe.mean(axis=0).unstack('ESTACION')
#df2=dframe['NOROESTE'].fillna(method='ffill').as_matrix()

#May 30, new imputation method used in R
df2= pd.read_csv("../data/imputed/data/NOROESTE.csv")

#Max normalization
df2=df2/np.nanmax(df2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-cec6075b434d> in <module>
#       3
#       4 #May 30, new imputation method used in R
# ----> 5 df2= pd.read_csv("../data/imputed/data/NOROESTE.csv")
#       6
#       7 #Max normalization
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# /Users/gucoloradoc/OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey/Tecnológico de Monterrey/Maestría/Tesis/2019-I/AQForecasting

# %%
df2= pd.read_csv("Monterrey/data/imputed/data/NOROESTE.csv")

#Max normalization
df2=df2/np.nanmax(df2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-207aeeb2c21b> in <module>
#       2
#       3 #Max normalization
# ----> 4 df2=df2/np.nanmax(df2)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/nanfunctions.py in nanmax(a, axis, out, keepdims)
#     409         # Slow, but safe for subclasses of ndarray
#     410         a, mask = _replace_nan(a, -np.inf)
# --> 411         res = np.amax(a, axis=axis, out=out, **kwargs)
#     412         if mask is None:
#     413             return res
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/core/fromnumeric.py in amax(a, axis, out, keepdims, initial)
#    2503     """
#    2504     return _wrapreduction(a, np.maximum, 'max', axis, None, out, keepdims=keepdims,
# -> 2505                           initial=initial)
#    2506
#    2507
#
# ...

# %%
df2
# Out:
#       format(NOROESTE$FECHA, "%Y-%m-%d %H:%M:%S")    CO          NO  \
# 0                             2012-01-01 00:00:00  2.08   16.600000
# 1                             2012-01-01 01:00:00  5.20  154.400000
# 2                             2012-01-01 02:00:00  2.51   47.400000
# 3                             2012-01-01 03:00:00  3.33   96.700000
# 4                             2012-01-01 04:00:00  1.26   10.000000
# 5                             2012-01-01 05:00:00  0.91    6.200000
# 6                             2012-01-01 06:00:00  1.68   29.300000
# 7                             2012-01-01 07:00:00  1.06   17.200000
# 8                             2012-01-01 08:00:00  0.66    6.400000
# 9                             2012-01-01 09:00:00  0.66    5.500000
# 10                            2012-01-01 10:00:00  0.50    4.500000
# 11                            2012-01-01 11:00:00  0.69    8.200000
# 12                            2012-01-01 12:00:00  0.95   10.700000
# ...

# %%
df2= pd.read_csv("Monterrey/data/imputed/data/NOROESTE.csv")



#Max normalization
#df2=df2/np.nanmax(df2)

# %%
df2
# Out:
#                      FECHA    CO          NO        NO2         NOX  \
# 0      2012-01-01 00:00:00  2.08   16.600000  57.800000   74.400000
# 1      2012-01-01 01:00:00  5.20  154.400000  60.400000  214.800000
# 2      2012-01-01 02:00:00  2.51   47.400000  51.100000   98.500000
# 3      2012-01-01 03:00:00  3.33   96.700000  49.000000  145.700000
# 4      2012-01-01 04:00:00  1.26   10.000000  39.300000   49.300000
# 16       2012-01-01 16:00:00
# 17       2012-01-01 17:00:00
# 18       2012-01-01 18:00:00
# 19       2012-01-01 19:00:00
# 20       2012-01-01 20:00:00
# 21       2012-01-01 21:00:00
# 22       2012-01-01 22:00:00
# 23       2012-01-01 23:00:00
# 24       2012-01-02 00:00:00
# 25       2012-01-02 01:00:00
# 26       2012-01-02 02:00:00
# 27       2012-01-02 03:00:00
# 28       2012-01-02 04:00:00
# 29       2012-01-02 05:00:00
#                 ...
# 52578    2017-12-30 18:00:00
# ...

# %%
type(df2["FECHA"])
# Out:
# pandas.core.series.Series

# %%
type(df2["FECHA"][1])
# Out:
# str

# %%
df2= pd.read_csv("Monterrey/data/imputed/data/NOROESTE.csv",
    parse_dates=["FECHA"])

# %%
type(df2["FECHA"][1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df2= pd.read_csv("Monterrey/data/imputed/data/NOROESTE.csv",
    parse_dates=["FECHA"])
df2=df2.set_index('FECHA')


#Max normalization
#df2=df2/np.nanmax(df2)

# %%
df2
# Out:
#                        CO          NO        NO2         NOX         O3  \
# FECHA
# 2012-01-01 00:00:00  2.08   16.600000  57.800000   74.400000   5.000000
# 2012-01-01 01:00:00  5.20  154.400000  60.400000  214.800000   8.000000
# 2012-01-01 02:00:00  2.51   47.400000  51.100000   98.500000   4.000000
# 2012-01-01 03:00:00  3.33   96.700000  49.000000  145.700000   6.000000
# 2012-01-01 04:00:00  1.26   10.000000  39.300000   49.300000   7.000000
# 2012-01-01 05:00:00  0.91    6.200000  27.400000   33.600000   8.000000
# 2012-01-01 06:00:00  1.68   29.300000  40.000000   69.300000   3.000000
# 2012-01-01 07:00:00  1.06   17.200000  23.100000   40.300000  12.000000
# 2012-01-01 08:00:00  0.66    6.400000  14.900000   21.300000  22.000000
# 2012-01-01 09:00:00  0.66    5.500000  12.700000   18.200000  25.000000
# 2012-01-01 10:00:00  0.50    4.500000   8.300000   12.800000  28.000000
# 2012-01-01 11:00:00  0.69    8.200000  16.600000   24.800000  22.000000
# ...

# %%
df2["PM2.5"].plot()

# %%
df2=df2/np.nanmax(df2)

# %%
df2["PM2.5"].plot()

# %%
# concentration in a delay.
def generator(data, lookback, delay, min_index, max_index,
              shuffle=False, batch_size=128, step=6):
    if max_index is None:
        max_index = len(data) - delay - 1
    i = min_index + lookback
    while 1:
        if shuffle:
            rows = np.random.randint(
                min_index + lookback, max_index, size=batch_size)
        else:
            if i + batch_size >= max_index:
                i = min_index + lookback
            rows = np.arange(i, min(i + batch_size, max_index))
            i += len(rows)

        samples = np.zeros((len(rows),
                           lookback // step,
                           data.shape[-1]))
        targets = np.zeros((len(rows),))
        for j, row in enumerate(rows):
            indices = range(rows[j] - lookback, rows[j], step)
            samples[j] = data[indices]
            #Here my targets could be O3(4),PM10(5),PM2.5(6)
            targets[j] = data[rows[j] + delay][5]
        yield samples, targets

# %%
lookback = 72
step = 1
delay = 24
batch_size = 1

train_gen = generator(df2,
                      lookback=lookback,
                      delay=delay,
                      min_index=0,
                      max_index=35000,
                      shuffle=True,
                      step=step, 
                      batch_size=batch_size)
val_gen = generator(df2,
                    lookback=lookback,
                    delay=delay,
                    min_index=35001,
                    max_index=40000,
                    step=step,
                    batch_size=batch_size)
test_gen = generator(df2,
                     lookback=lookback,
                     delay=delay,
                     min_index=40001,
                     max_index=None,
                     step=step,
                     batch_size=batch_size)

# %%
# This is how many steps to draw from `val_gen`
# in order to see the whole validation set:
val_steps = (40000 - 35001 - lookback) // batch_size

# This is how many steps to draw from `test_gen`
# in order to see the whole test set:
test_steps = (len(df2) - 40001 - lookback) // batch_size

# %%
def evaluate_naive_method():
    batch_maes = []
    for step in range(val_steps):
        samples, targets = next(val_gen)
        preds = samples[:, -1, 1]
        mae = np.mean(np.abs(preds - targets))
        batch_maes.append(mae)
    print(np.mean(batch_maes))
    
evaluate_naive_method()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-1bb1d5605744> in <module>
#       8     print(np.mean(batch_maes))
#       9
# ---> 10 evaluate_naive_method()
#
# <ipython-input-30-1bb1d5605744> in evaluate_naive_method()
#       2     batch_maes = []
#       3     for step in range(val_steps):
# ----> 4         samples, targets = next(val_gen)
#       5         preds = samples[:, -1, 1]
#       6         mae = np.mean(np.abs(preds - targets))
#
# <ipython-input-27-ef18f408b26b> in generator(data, lookback, delay, min_index, max_index, shuffle, batch_size, step)
#      21         for j, row in enumerate(rows):
#      22             indices = range(rows[j] - lookback, rows[j], step)
# ---> 23             samples[j] = data[indices]
#      24             #Here my targets could be O3(4),PM10(5),PM2.5(6)
#      25             targets[j] = data[rows[j] + delay][5]
# ...

# %%
df2= pd.read_csv("Monterrey/data/imputed/data/NOROESTE.csv",
    parse_dates=["FECHA"])
df2=df2.set_index('FECHA')

df2=df2.as_matrix()
#Max normalization
df2=df2/np.nanmax(df2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """

# %%
df2= pd.read_csv("Monterrey/data/imputed/data/NOROESTE.csv",
    parse_dates=["FECHA"])
df2=df2.set_index('FECHA')

df2=df2.values
#Max normalization
df2=df2/np.nanmax(df2)

# %%
# concentration in a delay.
def generator(data, lookback, delay, min_index, max_index,
              shuffle=False, batch_size=128, step=6):
    if max_index is None:
        max_index = len(data) - delay - 1
    i = min_index + lookback
    while 1:
        if shuffle:
            rows = np.random.randint(
                min_index + lookback, max_index, size=batch_size)
        else:
            if i + batch_size >= max_index:
                i = min_index + lookback
            rows = np.arange(i, min(i + batch_size, max_index))
            i += len(rows)

        samples = np.zeros((len(rows),
                           lookback // step,
                           data.shape[-1]))
        targets = np.zeros((len(rows),))
        for j, row in enumerate(rows):
            indices = range(rows[j] - lookback, rows[j], step)
            samples[j] = data[indices]
            #Here my targets could be O3(4),PM10(5),PM2.5(6)
            targets[j] = data[rows[j] + delay][5]
        yield samples, targets

# %%
lookback = 72
step = 1
delay = 24
batch_size = 1

train_gen = generator(df2,
                      lookback=lookback,
                      delay=delay,
                      min_index=0,
                      max_index=35000,
                      shuffle=True,
                      step=step, 
                      batch_size=batch_size)
val_gen = generator(df2,
                    lookback=lookback,
                    delay=delay,
                    min_index=35001,
                    max_index=40000,
                    step=step,
                    batch_size=batch_size)
test_gen = generator(df2,
                     lookback=lookback,
                     delay=delay,
                     min_index=40001,
                     max_index=None,
                     step=step,
                     batch_size=batch_size)

# %%
# This is how many steps to draw from `val_gen`
# in order to see the whole validation set:
val_steps = (40000 - 35001 - lookback) // batch_size

# This is how many steps to draw from `test_gen`
# in order to see the whole test set:
test_steps = (len(df2) - 40001 - lookback) // batch_size

# %%
def evaluate_naive_method():
    batch_maes = []
    for step in range(val_steps):
        samples, targets = next(val_gen)
        preds = samples[:, -1, 1]
        mae = np.mean(np.abs(preds - targets))
        batch_maes.append(mae)
    print(np.mean(batch_maes))
    
evaluate_naive_method()
# Out:
# 0.060779786547754996

# %%
from keras.models import Sequential
from keras import layers
from keras.optimizers import RMSprop

model = Sequential()
model.add(layers.Flatten(input_shape=(lookback // step, df2.shape[-1])))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(1))

model.compile(optimizer=RMSprop(), loss='mae')
history = model.fit_generator(train_gen,
                              steps_per_epoch=1,
                              epochs=100,
                              validation_data=val_gen,
                              validation_steps=val_steps)
# Out:
# Using TensorFlow backend.
# Limited tf.compat.v2.summary API due to missing TensorBoard installation
# Epoch 1/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.2208 - val_loss: 0.5363
# Epoch 2/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.6720 - val_loss: 0.1419
# Epoch 3/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.1557 - val_loss: 0.2016
# Epoch 4/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.2704 - val_loss: 0.0655
# Epoch 5/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.0355 - val_loss: 0.2209
# Epoch 6/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.2664 - val_loss: 0.0521
# Epoch 7/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.0583 - val_loss: 0.2555
# Epoch 8/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.2421 - val_loss: 0.0605
# Epoch 9/100
# ...

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from keras.models import Sequential
from keras import layers
from keras.optimizers import RMSprop

model = Sequential()
model.add(layers.Flatten(input_shape=(lookback // step, df2.shape[-1])))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(1))

model.compile(optimizer=RMSprop(), loss='mae')
history = model.fit_generator(train_gen,
                              steps_per_epoch=10,
                              epochs=1000,
                              validation_data=val_gen,
                              validation_steps=val_steps)
# Out:
# Epoch 1/1000
# 10/10 [==============================] - 5s 507ms/step - loss: 0.2340 - val_loss: 0.0773
# Epoch 2/1000
# 10/10 [==============================] - 4s 433ms/step - loss: 0.1038 - val_loss: 0.0645
# Epoch 3/1000
# 10/10 [==============================] - 4s 435ms/step - loss: 0.1205 - val_loss: 0.0367
# Epoch 4/1000
# 10/10 [==============================] - 4s 424ms/step - loss: 0.1187 - val_loss: 0.0360
# Epoch 5/1000
# 10/10 [==============================] - 4s 427ms/step - loss: 0.1343 - val_loss: 0.0409
# Epoch 6/1000
# 10/10 [==============================] - 4s 418ms/step - loss: 0.1147 - val_loss: 0.0483
# Epoch 7/1000
# 10/10 [==============================] - 4s 444ms/step - loss: 0.1758 - val_loss: 0.0629
# Epoch 8/1000
# 10/10 [==============================] - 4s 422ms/step - loss: 0.1119 - val_loss: 0.0799
# Epoch 9/1000
# 10/10 [==============================] - 4s 445ms/step - loss: 0.1136 - val_loss: 0.1311
# Epoch 10/1000
# ...

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
